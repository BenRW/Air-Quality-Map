# %%
import numpy as np
import pandas as pd

# %%
rural_data = pd.read_csv("rural_data.csv", delimiter = ";")
urban_data = pd.read_csv("urban_data.csv", delimiter = ";")
# Out:
# C:\Users\khana\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (2) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
rural_data.keys()
# Out:
# Index(['date', 'date_end', 'site', 'name', 'lat', 'lon', 'organisation',
#        'type', 'site_eu', 'type_alt', 'type_airbase', 'municipality.name',
#        'province.name', 'air.quality.area', 'bc', 'co', 'nh3', 'no', 'no2',
#        'nox', 'o3', 'ox', 'pm10', 'pm25', 'so2', 'benzeen', 'h2s',
#        'meta_paraxyleen', 'tolueen', 'ufp', 'wd', 'ws', 'ff', 'fx', 't',
#        't10n', 'td', 'sq', 'q', 'dr', 'hourly_rain', 'p', 'vv', 'n', 'rh'],
#       dtype='object')

# %%
rural_data['province.name']
# Out:
# 0              Limburg
# 1              Limburg
# 2              Limburg
# 3              Limburg
# 4              Limburg
#               ...
# 218995    Zuid-Holland
# 218996    Zuid-Holland
# 218997    Zuid-Holland
# 218998    Zuid-Holland
# 218999    Zuid-Holland
# Name: province.name, Length: 219000, dtype: object

# %%
import cartopy.crs as ccrs
import cartopy.io.shapereader as shpreader
import matplotlib.pyplot as plt

# Downloaded from https://gadm.org/download_country.html
fname = 'gadm41_NLD_1.shp' #0 is country border, 1 is provinces, 2 is municipalities

adm1_shapes = list(shpreader.Reader(fname).geometries())

plt.figure(figsize=(8,6))
ax = plt.axes(projection=ccrs.Mercator())

plt.title('Netherlands')
ax.coastlines(resolution='10m')

ax.add_geometries(adm1_shapes, ccrs.Mercator(),
                  edgecolor='black', facecolor='gray', alpha=0.5)

ax.set_extent([3, 7.5, 50.5, 54], ccrs.Mercator())

plt.show()
